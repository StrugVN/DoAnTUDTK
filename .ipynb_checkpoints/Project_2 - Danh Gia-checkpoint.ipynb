# %% [markdown]
# Lớp **Toán ứng dụng và thống kê - 17/11**
# Học kì II, 2019 - 2020

# %% [markdown]
# <hr>

# %% [markdown]
# <br>
# <center><b><font size="10">ĐỒ ÁN 2</font></b></center>
# <br>

# %% [markdown]
# <center>
#     <font size="4"><b>Nhóm thực hiện:</b></font><br>
#     Trần Minh Trí - 1712834&emsp;Nguyễn Nhật Trường - 1712852<br>
#     Lê Trường Vĩ - 1712900&emsp;Nguyễn Hửu Trí - 1712832<br>
# </center>

# %% [markdown]
# <hr>

# %%
import numpy as np
import pandas as pd

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

import pickle
import os.path

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Cho rằng test set có format giống training set

# %%
def read_data(fname):
    data = pd.read_csv(fname)
    return data.values[:, 1:].astype(float), data.values[:, [0]]

# %% [markdown]
# ## Dữ liệu đầu vào

# %%
X, Y = read_data("test.csv")

# %%
def process_StandardScaler(X):
    scaler = StandardScaler()
    return scaler.fit_transform(X)

# %%
X_test = process_StandardScaler(X)
X_test.shape, Y.shape
# Out:
# ((4072, 784), (4072, 1))

# %%
# lambda = 1e3
filename = "DA2_Logistic_Model.pkl"         
model = pickle.load(open(filename, 'rb'))
print("Loaded model in: ", filename)
# Out:
# Loaded model in:  DA2_Logistic_Model.pkl

# %% [markdown]
# ## Đánh giá

# %%
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / np.sum(cm).astype('float')
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(16, 12))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            if cm[i, j] == 0:
                plt.text(j, i, 0,
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
            else:
                plt.text(j, i, "{:0.3f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()


def model_validation(model, X_test, Y_test):
    prediction = model.predict(X_test)
    print("Match: ", model.score(X_test, Y_test)*100, "%")
    plot_confusion_matrix(confusion_matrix(prediction,  Y_test), np.unique(Y), title='Confusion matrix Normalized', cmap=None)
    plot_confusion_matrix(confusion_matrix(prediction,  Y_test), np.unique(Y), title='Confusion matrix', cmap=None, normalize=False)

# %%
model_validation(model, X_test, Y)
# Out:
# Match:  98.94400785854617 %
